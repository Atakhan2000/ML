# %%
import xgboost

# %%
boosting_model = xgboost.XGBClassifier(n_estimators=500)

boosting_model.fit(features_train, target_train)

y_train_predicted = boosting_model.predict_proba(features_train)[:, 1]
y_test_predicted = boosting_model.predict_proba(target_train)[:, 1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-07f10e8de535> in <module>()
#       4
#       5 y_train_predicted = boosting_model.predict_proba(features_train)
# ----> 6 y_test_predicted = boosting_model.predict_proba(target_train)
#
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py in predict_proba(self, data, ntree_limit, validate_features)
#     832         class_probs = self.get_booster().predict(test_dmatrix,
#     833                                                  ntree_limit=ntree_limit,
# --> 834                                                  validate_features=validate_features)
#     835         if self.objective == "multi:softprob":
#     836             return class_probs
#
# ...

# %%
train_auc = roc_auc_score(y_train, y_train_predicted)
test_auc = roc_auc_score(y_test, y_test_predicted)

plt.figure(figsize=(10,7))
plt.plot(*roc_curve(target_train, y_train_predicted)[:2], label='train AUC={:.4f}'.format(train_auc))
plt.plot(*roc_curve(target_test, y_test_predicted)[:2], label='test AUC={:.4f}'.format(test_auc))
legend_box = plt.legend(fontsize='large', framealpha=1).get_frame()
legend_box.set_facecolor("white")
legend_box.set_edgecolor("black")
plt.plot(np.linspace(0,1,100), np.linspace(0,1,100))
plt.show()

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('train.csv')
train = data.copy()

# %%
data.sample(5)
# Out:
#           Id   x_1   x_2   x_3   x_4  ...  x_297  x_298  x_299  x_300  Category
# 39997  39997  0.35  0.82  0.00  1.62  ...   0.00  -1.46   0.71   0.01       1.0
# 9469    9469  1.66 -0.26  0.02 -0.11  ...   0.00  -0.28   1.28   0.00      -1.0
# 16490  16490 -1.39  0.11 -0.02 -0.54  ...  -0.02   1.17  -0.53  -0.02       1.0
# 48296  48296  0.29  0.04 -0.10 -0.04  ...  -0.00   0.58   1.35  -0.04       1.0
# 79643  79643  1.33  0.71  0.03 -1.07  ...   0.00   0.92   0.63   0.11       1.0
#
# [5 rows x 302 columns]

# %%
target_col = 'Category'

# %%
features = train.drop(target_col, axis=1)
target = train[target_col]
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=1)

# %%
features.sample(5)
# Out:
#           Id   x_1   x_2   x_3   x_4  ...  x_296  x_297  x_298  x_299  x_300
# 81954  81954  0.29 -0.84 -0.00 -0.59  ...   0.58  -0.00  -3.59  -0.28  -0.01
# 72797  72797  0.01 -1.11 -0.00 -2.23  ...  -0.45  -0.06   0.09  -1.42  -0.00
# 57680  57680  0.27 -0.32 -0.00  0.34  ...  -1.25  -0.02  -0.69  -0.51  -0.02
# 49588  49588  0.99 -0.32 -0.00 -0.31  ...  -1.05  -0.05   1.62  -0.40  -0.00
# 10472  10472 -0.64 -0.64 -0.02 -0.85  ...   0.53  -0.02   0.95  -0.71  -0.18
#
# [5 rows x 301 columns]

# %%
target.sample(5)
# Out:
# 51650   -1.0
# 34236    1.0
# 10049    1.0
# 74235    1.0
# 48698   -1.0
# Name: Category, dtype: float64

# %%
model = XGBClassifier(n_estimators=5000)

# %%
model.fit(X_train, y_train)
# Out:
# XGBClassifier(n_estimators=5000)

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([ 1., -1.,  1., ...,  1.,  1., -1.])

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.954

# %%
X_test_ = pd.read_csv('test.csv')
submission = pd.read_csv('sample.csv')

submission['Category'] = model.predict(X_test_)
submission.to_csv('./my_submission3.csv')
